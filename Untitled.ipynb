# %% [markdown]
# # Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import yfinance as yf

get_ipython().run_line_magic('matplotlib', 'inline')

# %% [markdown]
# # Importing datasets

# %%
start = pd.to_datetime('2012-01-01')
end = pd.to_datetime('2017-01-01')

# %%
aapl = yf.download("AAPL", start=start, end=end)
cisco = yf.download("CSCO", start=start, end=end)
ibm = yf.download("IBM", start=start, end=end)
amzn = yf.download("AMZN", start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
for stock_df in (aapl, cisco, ibm, amzn):
    stock_df['Normed Return'] = stock_df['Close'] / stock_df.iloc[0]['Close']
    #print(stock_df.iloc[0]['Close'])
    #print(stock_df['Close'])

# %%
print(stock_df['Normed Return'])
# Out:
# Date
# 2012-01-03    1.000000
# 2012-01-04    0.991510
# 2012-01-05    0.992068
# 2012-01-06    1.019997
# 2012-01-09    0.997375
#                 ...
# 2016-12-23    4.248394
# 2016-12-27    4.308775
# 2016-12-28    4.312852
# 2016-12-29    4.273865
# 2016-12-30    4.188516
# Name: Normed Return, Length: 1258, dtype: float64

# %% [markdown]
# # Random Portfolio

# %%
for stock_df, alloc in zip([aapl, cisco, ibm, amzn], [.3,.2,.4,.1]):
    stock_df['Allocation'] = stock_df['Normed Return'] * alloc

# %%
for stock_df in (aapl, cisco, ibm, amzn):
    stock_df['Position Values'] = stock_df['Allocation']*1000000

# %%
portfolio_val = pd.concat([aapl['Position Values'], cisco['Position Values'], ibm['Position Values'], amzn['Position Values']], axis=1)
portfolio_val.columns = ['AAPL Pos', 'CISCO Pos', 'IBM Pos', 'AMZN Pos']

portfolio_val['Total Pos'] = portfolio_val.sum(axis=1)

# %%
portfolio_val.drop('Total Pos', axis=1).plot(kind='line', figsize=(12,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
portfolio_val['Total Pos'].plot(figsize=(10,8))
plt.title('Total Portfolio Value')
# Out:
# Text(0.5, 1.0, 'Total Portfolio Value')

# %% [markdown]
# # Portfolio Statistics

# %%
portfolio_val['Daily Return'] = portfolio_val['Total Pos'].pct_change(1)

# %%
cum_ret = 100 * (portfolio_val['Total Pos'][-1] / portfolio_val['Total Pos'][0] -1)
print('Our return was {}%'.format(cum_ret))
# Out:
# Our return was 84.74606589294386%

# %%
SR = portfolio_val['Daily Return'].mean() / portfolio_val['Daily Return'].std()

# %%
print("Annulized Sharpe Ratio: " + str((252**0.5)*SR))
# Out:
# Annulized Sharpe Ratio: 0.8173397898670816

# %% [markdown]
# # Portfolio Optimization

# %%
stocks = pd.concat([aapl['Normed Return'],cisco['Normed Return'],ibm['Normed Return'],amzn['Normed Return']], axis=1)
stocks.columns = ['aapl','cisco','ibm','amzn']

# %%
stocks = pd.concat([aapl['Close'],cisco['Close'],ibm['Close'],amzn['Close']], axis=1)
stocks.columns = ['aapl','cisco','ibm','amzn']

# %%
mean_daily_ret = stocks.pct_change(1).mean()

stocks.pct_change(1).corr()
# Out:
#            aapl     cisco       ibm      amzn
# aapl   1.000000  0.302072  0.297804  0.235724
# cisco  0.302072  1.000000  0.424469  0.284914
# ibm    0.297804  0.424469  1.000000  0.258554
# amzn   0.235724  0.284914  0.258554  1.000000

# %%
log_ret = np.log(stocks/stocks.shift(1)).dropna()

# %%
log_ret['aapl'].hist(bins=100, figsize=(12,6))
plt.show()
log_ret['cisco'].hist(bins=100, figsize=(12,6))
plt.show()
log_ret['ibm'].hist(bins=100, figsize=(12,6))
plt.show()
log_ret['amzn'].hist(bins=100, figsize=(12,6))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Monte Carlo Simulation

# %%
np.random.seed(101)
num_ports = 25000

all_weights = np.zeros((num_ports,len(stocks.columns)))
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharpe_arr = np.zeros(num_ports)

for ind in range(num_ports):

    weights = np.array(np.random.random(4))
    weights = weights / np.sum(weights)
    all_weights[ind,:] = weights

    ret_arr[ind] = np.sum((log_ret.mean() * weights) *252)
    vol_arr[ind] = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))

    sharpe_arr[ind] = ret_arr[ind] / vol_arr[ind]

print('Max Sharpe Ratio: ' + str(sharpe_arr.max()))
# Out:
# Max Sharpe Ratio: 1.0300968285328187

# %%
plt.figure(figsize=(12,8))
plt.scatter(vol_arr, ret_arr, c=sharpe_arr)
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')
# Out:
# Text(0, 0.5, 'Return')

# %% [markdown]
# # Calculated using Optimization Solver

# %%
def get_ret_vol_sr(weights):
    weights = np.array(weights)
    ret = np.sum(log_ret.mean() * weights) * 252
    vol = np.sqrt(np.dot(weights.T, np.dot(log_ret.cov() * 252, weights)))
    sr = ret / vol
    return np.array([ret,vol,sr])

def neg_sharpe(weights):
    return  get_ret_vol_sr(weights)[2] * -1

def check_sum(weights):
    return np.sum(weights) - 1

def minimize_volatility(weights):
    return  get_ret_vol_sr(weights)[1]

# %%
cons = ({'type':'eq','fun': check_sum})
bounds = ((0, 1), (0, 1), (0, 1), (0, 1))
init_guess = [0.25,0.25,0.25,0.25]

# %%
opt_results = minimize(neg_sharpe, init_guess, method='SLSQP', bounds=bounds, constraints=cons)
get_ret_vol_sr(opt_results.x)
# Out:
# array([0.21890447, 0.21242799, 1.03048788])

# %%
frontier_y = np.linspace(0,0.3,100)
frontier_volatility = []

for possible_return in frontier_y:
    cons = ({'type':'eq','fun': check_sum},
            {'type':'eq','fun': lambda w: get_ret_vol_sr(w)[0] - possible_return})
    
    result = minimize(minimize_volatility, init_guess, method='SLSQP', bounds=bounds, constraints=cons)
    frontier_volatility.append(result['fun'])

# %%
plt.figure(figsize=(12,8))
plt.scatter(vol_arr, ret_arr, c=sharpe_arr)
plt.colorbar(label='Sharpe Ratio')
plt.xlabel('Volatility')
plt.ylabel('Return')

plt.plot(frontier_volatility,frontier_y,'g--',linewidth=3)
